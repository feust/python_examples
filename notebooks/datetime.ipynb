# %%
import sys

sys.version
# Out:
# '3.10.5 (tags/v3.10.5:f377153, Jun  6 2022, 16:14:13) [MSC v.1929 64 bit (AMD64)]'

# %%
import numpy as np
import datetime as dt

# %%
dt.datetime.today()
# Out:
# datetime.datetime(2022, 11, 4, 7, 47, 16, 796879)

# %%
start =  dt.datetime.today()
start = dt.date(start.year, start.month, start.day)
end = dt.date( 2022, 12, 12 )

days = np.busday_count( start, end,  [1,1,1,1,1,0,0] )

print(f'remaining workdays {days}')
# Out:
# remaining workdays 26
